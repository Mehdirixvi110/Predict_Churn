# %%
# !pip install |scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.0 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 6.9 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 6.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 6.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 6.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    - -------------------------------------- 1.8/44.5 MB ? eta -:--:--
# ...
